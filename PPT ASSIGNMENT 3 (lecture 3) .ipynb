# %% [markdown]
# ## PPT ASSIGNMENT

# %% [markdown]
# 1 Scenario: A company wants to analyze the sales performance of its products in different regions. They have collected the following data:
#  Region A: [10, 15, 12, 8, 14]
#  Region B: [18, 20, 16, 22, 25]
#  Calculate the mean sales for each region.

# %% [markdown]
# To calculate the mean sales for each region, you need to add up the sales values for each region and divide by the number of data points.
#
# Let's calculate the mean sales for each region:
#
# Region A: [10, 15, 12, 8, 14]
#
# To find the mean, sum up the values and divide by the total number of data points:
# Mean of Region A = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
#
# Therefore, the mean sales for Region A is 11.8.
#
# Region B: [18, 20, 16, 22, 25]
#
# Mean of Region B = (18 + 20 + 16 + 22 + 25) / 5 = 101 / 5 = 20.2
#
# Therefore, the mean sales for Region B is 20.2.
#
# The mean sales for each region are as follows:
# Region A: 11.8
# Region B: 20.2

# %% [markdown]
# 2  Scenario: A survey is conducted to measure customer satisfaction on a scale of 1 to 5. The data collected is as follows:
#    [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#    Calculate the mode of the survey responses.

# %% [markdown]
# To calculate the mode of the survey responses, you need to determine the value or values that appear most frequently in the dataset.
#
# The given survey responses are: [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#
# To find the mode, we will count the frequency of each unique value and identify the one(s) with the highest frequency.
#
# Frequency of 2: 2
# Frequency of 3: 2
# Frequency of 4: 3
# Frequency of 5: 3
#
# The values 4 and 5 have the highest frequency, occurring 3 times each. Therefore, the mode of the survey responses is 4 and 5.
#
# Note that it is possible to have multiple modes if there are multiple values with the same highest frequency. In this case, both 4 and 5 are the modes of the survey responses.

# %% [markdown]
# 3  Scenario: A company wants to compare the salaries of two departments. The salary data for Department A and Department B are as follows:
#    Department A: [5000, 6000, 5500, 7000]
#    Department B: [4500, 5500, 5800, 6000, 5200]
#    Calculate the median salary for each department.

# %% [markdown]
# To calculate the median salary for each department, you need to arrange the salary data in ascending order and find the middle value(s) of the dataset.
#
# Department A: [5000, 6000, 5500, 7000]
#
# First, let's sort the salaries in ascending order:
# [5000, 5500, 6000, 7000]
#
# Since the dataset has an odd number of values, the median is the middle value. In this case, the median salary for Department A is 5500.
#
# Department B: [4500, 5500, 5800, 6000, 5200]
#
# Sorting the salaries in ascending order:
# [4500, 5200, 5500, 5800, 6000]
#
# Again, since the dataset has an odd number of values, the median is the middle value. In this case, the median salary for Department B is 5500.
#
# Therefore, the median salary for Department A is 5500, and the median salary for Department B is also 5500.

# %% [markdown]
# 4  Scenario: A data analyst wants to determine the variability in the daily stock prices of a company. The data collected is as follows:
#    [25.5, 24.8, 26.1, 25.3, 24.9]
#    Calculate the range of the stock prices.

# %% [markdown]
# To calculate the range of stock prices, you need to find the difference between the highest and lowest values in the dataset. In this case, the data analyst wants to determine the variability in the daily stock prices of a company based on the following data:
#
# [25.5, 24.8, 26.1, 25.3, 24.9]
#
# To calculate the range, follow these steps:
#
# Step 1: Identify the highest value in the dataset.
# In this case, the highest value is 26.1.
#
# Step 2: Identify the lowest value in the dataset.
# In this case, the lowest value is 24.8.
#
# Step 3: Calculate the range by subtracting the lowest value from the highest value.
# Range = Highest value - Lowest value
# Range = 26.1 - 24.8
# Range = 1.3
#
# Therefore, the range of the stock prices in the given dataset is 1.3.

# %% [markdown]
# Therefore, the range of the stock prices is 1.3. This means that the highest stock price was 1.3 points higher than the lowest stock price.

# %% [markdown]
# 5  Scenario: A study is conducted to compare the performance of two different teaching methods. The test scores of the students in each group are as follows:
#    Group A: [85, 90, 92, 88, 91]
#    Group B: [82, 88, 90, 86, 87]
#    Perform a t-test to determine if there is a significant difference in the mean scores between the two groups.

# %% [markdown]
# To perform a t-test and determine if there is a significant difference in the mean scores between the two groups (Group A and Group B), you can use a two-sample independent t-test. The null hypothesis (H0) for this test is that there is no significant difference between the means of the two groups, while the alternative hypothesis (H1) is that there is a significant difference.
#
# In this case, we have the following data:
#
# Group A: [85, 90, 92, 88, 91]
# Group B: [82, 88, 90, 86, 87]
#
# To perform the t-test, you can follow these steps:
#
# Step 1: Calculate the sample means and sample standard deviations for each group.
# Mean of Group A (x̄A) = (85 + 90 + 92 + 88 + 91) / 5 = 88.4
# Mean of Group B (x̄B) = (82 + 88 + 90 + 86 + 87) / 5 = 86.6
#
# Standard deviation of Group A (sA) = sqrt(((85 - 88.4)^2 + (90 - 88.4)^2 + (92 - 88.4)^2 + (88 - 88.4)^2 + (91 - 88.4)^2) / (5 - 1)) = 2.949
# Standard deviation of Group B (sB) = sqrt(((82 - 86.6)^2 + (88 - 86.6)^2 + (90 - 86.6)^2 + (86 - 86.6)^2 + (87 - 86.6)^2) / (5 - 1)) = 2.701
#
# Step 2: Calculate the t-statistic.
# t = (x̄A - x̄B) / sqrt((sA^2 / nA) + (sB^2 / nB))
# = (88.4 - 86.6) / sqrt((2.949^2 / 5) + (2.701^2 / 5))
# = 1.8 / sqrt(1.764 + 1.365)
# = 1.8 / sqrt(3.129)
# = 1.8 / 1.77
# = 1.017
#
# Step 3: Determine the degrees of freedom.
# Degrees of freedom (df) = nA + nB - 2 = 5 + 5 - 2 = 8
#
# Step 4: Determine the critical value.
# For a two-tailed test at a significance level of α = 0.05, the critical value is t-critical = ±2.306 (using a t-distribution table or statistical software).
#
# Step 5: Compare the t-statistic with the critical value and make a decision.
# Since |t-statistic| = 1.017 < |t-critical| = 2.306, we fail to reject the null hypothesis.
#
# Conclusion:
# There is not enough evidence to suggest a significant difference in the mean scores between Group A and Group B at a significance level of α = 0.05.

# %% [markdown]
# 6  Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
#    Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#    Sales (in thousands): [25, 30, 28, 20, 26]
#    Calculate the correlation coefficient between advertising expenditure and sales.

# %% [markdown]
# To calculate the correlation coefficient between advertising expenditure and sales, you can use the Pearson correlation coefficient formula. The Pearson correlation coefficient, denoted as "r," measures the strength and direction of the linear relationship between two variables.
#
# In this case, we have the following data:
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# To calculate the correlation coefficient, you can follow these steps:
#
# Step 1: Calculate the mean of both variables.
# Mean of Advertising Expenditure (x̄) = (10 + 15 + 12 + 8 + 14) / 5 = 11.8
# Mean of Sales (ȳ) = (25 + 30 + 28 + 20 + 26) / 5 = 25.8
#
# Step 2: Calculate the deviations from the mean for both variables.
# Deviations from the mean for Advertising Expenditure (x) = [10 - 11.8, 15 - 11.8, 12 - 11.8, 8 - 11.8, 14 - 11.8] = [-1.8, 3.2, 0.2, -3.8, 2.2]
# Deviations from the mean for Sales (y) = [25 - 25.8, 30 - 25.8, 28 - 25.8, 20 - 25.8, 26 - 25.8] = [-0.8, 4.2, 2.2, -5.8, 0.2]
#
# Step 3: Calculate the product of the deviations for each pair of observations.
# Product of deviations = [-1.8 * -0.8, 3.2 * 4.2, 0.2 * 2.2, -3.8 * -5.8, 2.2 * 0.2] = [1.44, 13.44, 0.44, 22.04, 0.44]
#
# Step 4: Calculate the sum of the product of deviations.
# Sum of the product of deviations = 1.44 + 13.44 + 0.44 + 22.04 + 0.44 = 37.8
#
# Step 5: Calculate the standard deviation for each variable.
# Standard deviation of Advertising Expenditure (sx) = sqrt(((-1.8)^2 + 3.2^2 + 0.2^2 + (-3.8)^2 + 2.2^2) / (5 - 1)) = 2.78
# Standard deviation of Sales (sy) = sqrt(((-0.8)^2 + 4.2^2 + 2.2^2 + (-5.8)^2 + 0.2^2) / (5 - 1)) = 3.77
#
# Step 6: Calculate the correlation coefficient (r).
# r = (Sum of the product of deviations) / (n * sx * sy)
# = 37.8 / (5 * 2.78 * 3.77)
# = 37.8 / (41.74)
# = 0.906
#
# Therefore, the correlation coefficient between advertising expenditure and sales is 0.906, indicating a strong positive linear relationship between the two variables.

# %% [markdown]
# 7  Scenario: A survey is conducted to measure the heights of a group of people. The data collected is as follows:
#    [160, 170, 165, 155, 175, 180, 170]
#    Calculate the standard deviation of the heights.

# %% [markdown]
# To calculate the standard deviation of the heights, you can follow these steps:
#
# Step 1: Calculate the mean of the heights.
# To find the mean, add up all the heights and divide by the total number of data points.
#
# Mean = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7
# Mean = 1175 / 7
# Mean ≈ 167.86
#
# Step 2: Calculate the deviations from the mean for each height.
# Deviation = Height - Mean
#
# Deviation for 160 = 160 - 167.86 ≈ -7.86
# Deviation for 170 = 170 - 167.86 ≈ 2.14
# Deviation for 165 = 165 - 167.86 ≈ -2.86
# Deviation for 155 = 155 - 167.86 ≈ -12.86
# Deviation for 175 = 175 - 167.86 ≈ 7.14
# Deviation for 180 = 180 - 167.86 ≈ 12.14
# Deviation for 170 = 170 - 167.86 ≈ 2.14
#
# Step 3: Square each deviation.
# Squared Deviation = Deviation^2
#
# Squared Deviation for 160 ≈ (-7.86)^2 = 61.87
# Squared Deviation for 170 ≈ (2.14)^2 = 4.57
# Squared Deviation for 165 ≈ (-2.86)^2 = 8.19
# Squared Deviation for 155 ≈ (-12.86)^2 = 165.42
# Squared Deviation for 175 ≈ (7.14)^2 = 51.07
# Squared Deviation for 180 ≈ (12.14)^2 = 147.29
# Squared Deviation for 170 ≈ (2.14)^2 = 4.57
#
# Step 4: Calculate the mean of the squared deviations.
# Mean of Squared Deviations = (61.87 + 4.57 + 8.19 + 165.42 + 51.07 + 147.29 + 4.57) / 7
# Mean of Squared Deviations ≈ 61.43
#
# Step 5: Take the square root of the mean of squared deviations to find the standard deviation.
# Standard Deviation = sqrt(Mean of Squared Deviations)
# Standard Deviation ≈ sqrt(61.43)
# Standard Deviation ≈ 7.84
#
# Therefore, the standard deviation of the heights in the given dataset is approximately 7.84.

# %% [markdown]
# 8  Scenario: A company wants to analyze the relationship between employee tenure and job satisfaction. The data collected is as follows:
#    Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
#    Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#    Perform a linear regression analysis to predict job satisfaction based on employee tenure.

# %% [markdown]
# To perform a linear regression analysis to predict job satisfaction based on employee tenure, you can use the collected data. Here's a step-by-step process:
#
# Organize the Data:
#
# Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
# Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
# Visualize the Data:
#
# Plot the data points on a scatter plot to visualize the relationship between employee tenure and job satisfaction.
# Prepare the Data:
#
# Convert the data into two arrays or columns: one for employee tenure and the other for job satisfaction.
# Ensure that the data is in a format that can be used for linear regression analysis.
# Split the Data:
#
# Split the data into a training set and a test set. This is important to evaluate the model's performance on unseen data.
# The typical split is around 70-80% of the data for training and 20-30% for testing.
# Fit the Linear Regression Model:
#
# Use a linear regression algorithm from a machine learning library (e.g., scikit-learn) to fit the model to the training data.
# The model will learn the relationship between employee tenure and job satisfaction and estimate the coefficients.
# Make Predictions:
#
# Once the model is trained, use it to make predictions on the test data or any new data point.
# The model will use the learned coefficients to predict job satisfaction based on employee tenure.
# Evaluate the Model:
#
# Assess the performance of the model by comparing the predicted job satisfaction values with the actual job satisfaction values from the test set.
# Calculate evaluation metrics such as mean squared error (MSE) or R-squared to quantify the model's accuracy.
# Interpret the Results:
#
# Interpret the coefficients obtained from the linear regression model.
# The coefficient of employee tenure represents the change in job satisfaction associated with a unit change in employee tenure.
# Analyze the coefficient's sign and magnitude to understand the direction and strength of the relationship.

# %% [markdown]
# 9  Scenario: A study is conducted to compare the effectiveness of two different medications. The recovery times of the patients in each group are as follows:
#    Medication A: [10, 12, 14, 11, 13]
#    Medication B: [15, 17, 16, 14, 18]
#    Perform an analysis of variance (ANOVA) to determine if there is a significant difference in the mean recovery times between the two medications.

# %% [markdown]
# To perform a linear regression analysis to predict job satisfaction based on employee tenure, you can use the following steps:
#
# Step 1: Prepare the data.
# The data collected for employee tenure and job satisfaction is as follows:
#
# Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
# Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
# Make sure that the data is properly aligned, meaning that the job satisfaction ratings correspond to the correct employee tenure values.
#
# Step 2: Calculate the correlation coefficient.
# Calculate the correlation coefficient (r) to determine the strength and direction of the linear relationship between employee tenure and job satisfaction.
#
# You can use a statistical software or a programming language with appropriate libraries to calculate the correlation coefficient. The correlation coefficient ranges between -1 and 1, where -1 indicates a strong negative correlation, 1 indicates a strong positive correlation, and 0 indicates no correlation.
#
# Step 3: Plot the data.
# Create a scatter plot with employee tenure on the x-axis and job satisfaction on the y-axis. Each data point represents an employee's tenure and corresponding job satisfaction rating.
#
# Step 4: Perform linear regression analysis.
# Perform a linear regression analysis to determine the equation of the regression line that best fits the data. The equation is typically in the form of y = mx + b, where y represents the predicted job satisfaction, x represents the employee tenure, m represents the slope of the line, and b represents the y-intercept.
#
# Again, you can use statistical software or programming languages with appropriate libraries to perform linear regression analysis.
#
# Step 5: Interpret the results.
# Interpret the results of the linear regression analysis, including the slope, intercept, and the coefficient of determination (R-squared). The slope indicates how much the job satisfaction is expected to change for each unit change in employee tenure. The intercept represents the predicted job satisfaction when the tenure is zero. The R-squared value indicates the proportion of the variance in job satisfaction that can be explained by employee tenure.
#
# Performing these steps with the given data will provide you with the linear regression analysis results and allow you to predict job satisfaction based on employee tenure.

# %% [markdown]
# 10  Scenario: A company wants to analyze customer feedback ratings on a scale of 1 to 10. The data collected is
#     as follows:
#     [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#     Calculate the 75th percentile of the feedback ratings.

# %% [markdown]
# To calculate the 75th percentile of the feedback ratings, you can follow these steps:
#
# Step 1: Sort the data in ascending order.
# The data collected for the customer feedback ratings is as follows:
# [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#
# Sorting the data in ascending order gives:
# [6, 7, 7, 8, 8, 8, 8, 9, 9, 10]
#
# Step 2: Calculate the index of the 75th percentile.
# The index of the 75th percentile can be calculated using the formula:
# Index = (P / 100) * (N - 1) + 1
#
# where P is the desired percentile (in this case, 75), and N is the total number of data points.
#
# Index = (75 / 100) * (10 - 1) + 1
# Index ≈ 7.25
#
# Step 3: Find the value at the calculated index.
# Since the index is not a whole number, we can use linear interpolation to estimate the value at the index. Linear interpolation involves finding the two nearest values to the index and calculating a weighted average based on their positions.
#
# The two nearest values to the index 7.25 are 7 and 8, corresponding to the positions 7 and 8, respectively.
#
# Weighted Average = (1 - Fraction) * Value1 + Fraction * Value2
#
# Fraction = Index - Integer part of Index
# = 7.25 - 7
# = 0.25
#
# Value1 = 7 (at position 7)
# Value2 = 8 (at position 8)
#
# Weighted Average = (1 - 0.25) * 7 + 0.25 * 8
# = 0.75 * 7 + 0.25 * 8
# = 5.25 + 2
# = 7.25
#
# Therefore, the 75th percentile of the feedback ratings is approximately 7.25.

# %% [markdown]
# 11  Scenario: A quality control department wants to test the weight consistency of a product. The weights of a sample of products are as follows:
#     [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#     Perform a hypothesis test to determine if the mean weight differs significantly from 10 grams.

# %% [markdown]
# To perform a hypothesis test to determine if the mean weight differs significantly from 10 grams, you can use the following steps:
#
# Step 1: State the null and alternative hypotheses.
# Null hypothesis (H0): The mean weight is equal to 10 grams.
# Alternative hypothesis (Ha): The mean weight differs from 10 grams.
#
# Step 2: Calculate the sample mean.
# Calculate the mean weight of the sample using the given data.
#
# Mean = (10.2 + 9.8 + 10.0 + 10.5 + 10.3 + 10.1) / 6
# Mean = 61.9 / 6
# Mean = 10.32
#
# Step 3: Calculate the sample standard deviation.
# Calculate the standard deviation of the sample to estimate the variability of the weights.
#
# Standard Deviation = sqrt([(10.2 - 10.32)^2 + (9.8 - 10.32)^2 + (10.0 - 10.32)^2 + (10.5 - 10.32)^2 + (10.3 - 10.32)^2 + (10.1 - 10.32)^2] / 5)
# Standard Deviation = sqrt([(-0.12)^2 + (-0.52)^2 + (-0.32)^2 + (0.18)^2 + (0.02)^2 + (-0.22)^2] / 5)
# Standard Deviation = sqrt([0.0144 + 0.2704 + 0.1024 + 0.0324 + 0.0004 + 0.0484] / 5)
# Standard Deviation = sqrt(0.4684 / 5)
# Standard Deviation = sqrt(0.09368)
# Standard Deviation ≈ 0.306
#
# Step 4: Set the significance level.
# Choose a significance level (α) to determine the critical value for the hypothesis test. Common choices include 0.05 or 0.01.
#
# Step 5: Calculate the test statistic.
# Calculate the test statistic based on the sample mean, the population mean under the null hypothesis, and the sample standard deviation.
#
# t = (Mean - Population Mean) / (Standard Deviation / sqrt(n))
# t = (10.32 - 10) / (0.306 / sqrt(6))
# t = 0.32 / (0.306 / sqrt(6))
# t ≈ 0.32 / 0.125
# t ≈ 2.56
#
# Step 6: Determine the critical value and compare it with the calculated test statistic.
# Based on the chosen significance level and the degrees of freedom (n - 1 = 6 - 1 = 5), you can use a t-table or statistical software to determine the critical value for a two-tailed test.
#
# If the absolute value of the calculated test statistic is greater than the critical value, you reject the null hypothesis. Otherwise, you fail to reject the null hypothesis.
#
# Step 7: Interpret the results.
# If the absolute value of the calculated test statistic is greater than the critical value, you can conclude that the mean weight differs significantly from 10 grams. On the other hand, if the absolute value of the calculated test statistic is not greater than the critical value, you cannot conclude that the mean weight differs significantly.
#
# Performing these steps with the given data and chosen significance level will allow you to perform the hypothesis test and determine if the mean weight differs significantly from 10 grams.

# %% [markdown]
# 12  Scenario: A company wants to analyze the click-through rates of two different website designs. The number of clicks for each design is as follows:
#     Design A: [100, 120, 110, 90, 95]
#     Design B: [80, 85, 90, 95, 100]
#     Perform a chi-square test to determine if there is a significant difference in the click-through rates between the two designs.

# %% [markdown]
# To perform a chi-square test to determine if there is a significant difference in the click-through rates between the two designs, you can use the following steps:
#
# Step 1: State the null and alternative hypotheses.
# Null hypothesis (H0): There is no significant difference in the click-through rates between Design A and Design B.
# Alternative hypothesis (Ha): There is a significant difference in the click-through rates between Design A and Design B.
#
# Step 2: Create a contingency table.
# Create a contingency table that shows the observed frequencies of clicks for each design.
#
# Clicks  Design A Design B
#              100 80
#              120 85
#              110 90
#               90 95
#               95 100
#
# Step 3: Calculate the expected frequencies.
# Calculate the expected frequencies under the assumption of no difference between the designs. This is done by finding the row totals, column totals, and the total number of observations, and then applying the formula: expected frequency = (row total * column total) / total number of observations.
#
# In this case, the total number of observations is 5 (since there are 5 clicks for each design).
#
# Expected frequency for Design A and 100 clicks = (5 * 280) / 10 = 140
# Expected frequency for Design A and 120 clicks = (5 * 275) / 10 = 137.5
# Expected frequency for Design A and 110 clicks = (5 * 270) / 10 = 135
# Expected frequency for Design A and 90 clicks = (5 * 275) / 10 = 137.5
# Expected frequency for Design A and 95 clicks = (5 * 280) / 10 = 140
#
# Expected frequency for Design B and 80 clicks = (5 * 220) / 10 = 110
# Expected frequency for Design B and 85 clicks = (5 * 225) / 10 = 112.5
# Expected frequency for Design B and 90 clicks = (5 * 230) / 10 = 115
# Expected frequency for Design B and 95 clicks = (5 * 225) / 10 = 112.5
# Expected frequency for Design B and 100 clicks = (5 * 220) / 10 = 110
#
# Step 4: Calculate the chi-square test statistic.
# Calculate the chi-square test statistic using the formula:
# chi-square = sum((observed frequency - expected frequency)^2 / expected frequency)
#
# chi-square = ((100 - 140)^2 / 140) + ((120 - 137.5)^2 / 137.5) + ((110 - 135)^2 / 135) + ((90 - 137.5)^2 / 137.5) + ((95 - 140)^2 / 140) + ((80 - 110)^2 / 110) + ((85 - 112.5)^2 / 112.5) + ((90 - 115)^2 / 115) + ((95 - 112.5)^2 / 112.5) + ((100 - 110)^2 / 110)
#
# chi-square = (1600 / 140) + (18.75 / 137.5) + (81 / 135) + (18.75 / 137.5) + (1600 / 140) + (900 / 110) + (506.25 / 112.5) + (75 / 115) + (18.75 / 112.5) + (100 / 110)
#
# chi-square = 11.43 + 0.136 + 0.6 + 0.136 + 11.43 + 8.18 + 4.5 + 0.652 + 0.166 + 0.91
# chi-square = 37.71
#
# Step 5: Determine the degrees of freedom.
# The degrees of freedom for a chi-square test of independence are calculated using the formula: degrees of freedom = (number of rows - 1) * (number of columns - 1).
#
# In this case, there are 5 rows and 2 columns, so the degrees of freedom = (5 - 1) * (2 - 1) = 4.
#
# Step 6: Determine the critical value.
# Based on the chosen significance level (e.g., α = 0.05) and the degrees of freedom, you can use a chi-square distribution table or statistical software to determine the critical value.
#
# Step 7: Compare the calculated chi-square test statistic with the critical value.
# If the calculated chi-square test statistic is greater than the critical value, you reject the null hypothesis. Otherwise, you fail to reject the null hypothesis.
#
# Step 8: Interpret the results.
# If the calculated chi-square test statistic is greater than the critical value, you can conclude that there is a significant difference in the click-through rates between Design A and Design B. On the other hand, if the calculated chi-square test statistic is not greater than the critical value, you cannot conclude that there is a significant difference.
#
# Performing these steps with the given data and chosen significance level will allow you to perform the chi-square test and determine if there is a significant difference in the click-through rates between the two designs.

# %% [markdown]
# 13  Scenario: A survey is conducted to measure customer satisfaction with a product on a scale of 1 to 10. The data collected is as follows:
#     [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#     Calculate the 95% confidence interval for the population mean satisfaction score.

# %% [markdown]
# To calculate the 95% confidence interval for the population mean satisfaction score, you can follow these steps:
#
# Step 1: Calculate the sample mean.
# Calculate the mean satisfaction score of the sample using the given data.
#
# Mean = (7 + 9 + 6 + 8 + 10 + 7 + 8 + 9 + 7 + 8) / 10
# Mean = 79 / 10
# Mean = 7.9
#
# Step 2: Calculate the sample standard deviation.
# Calculate the standard deviation of the sample to estimate the variability of the satisfaction scores.
#
# Standard Deviation = sqrt([(7 - 7.9)^2 + (9 - 7.9)^2 + (6 - 7.9)^2 + (8 - 7.9)^2 + (10 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2 + (9 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2] / 9)
# Standard Deviation = sqrt([(-0.9)^2 + (1.1)^2 + (-1.9)^2 + (0.1)^2 + (2.1)^2 + (-0.9)^2 + (0.1)^2 + (1.1)^2 + (-0.9)^2 + (0.1)^2] / 9)
# Standard Deviation = sqrt([0.81 + 1.21 + 3.61 + 0.01 + 4.41 + 0.81 + 0.01 + 1.21 + 0.81 + 0.01] / 9)
# Standard Deviation = sqrt(13.08 / 9)
# Standard Deviation ≈ sqrt(1.453)
# Standard Deviation ≈ 1.206
#
# Step 3: Determine the sample size.
# The sample size is given as 10 in this case.
#
# Step 4: Determine the critical value.
# To calculate the 95% confidence interval, we need to find the critical value associated with a 95% confidence level. For a large enough sample size (greater than 30), we can use the z-distribution.
#
# For a 95% confidence level, the critical value is approximately 1.96.
#
# Step 5: Calculate the standard error.
# The standard error is calculated by dividing the sample standard deviation by the square root of the sample size.
#
# Standard Error = Standard Deviation / sqrt(sample size)
# Standard Error = 1.206 / sqrt(10)
# Standard Error ≈ 0.381
#
# Step 6: Calculate the margin of error.
# The margin of error is determined by multiplying the standard error by the critical value.
#
# Margin of Error = Critical Value * Standard Error
# Margin of Error = 1.96 * 0.381
# Margin of Error ≈ 0.747
#
# Step 7: Calculate the lower and upper bounds of the confidence interval.
# The lower bound is found by subtracting the margin of error from the sample mean, and the upper bound is found by adding the margin of error to the sample mean.
#
# Lower Bound = Sample Mean - Margin of Error
# Lower Bound = 7.9 - 0.747
# Lower Bound ≈ 7.153
#
# Upper Bound = Sample Mean + Margin of Error
# Upper Bound = 7.9 + 0.747
# Upper Bound ≈ 8.647
#
# Step 8: Interpret the results.
# The 95% confidence interval for the population mean satisfaction score is approximately 7.153 to 8.647. This means that we can be 95% confident that the true population mean satisfaction score falls within this range based on the sample data.
#
# Performing these steps with the given data will allow you to calculate the 95% confidence interval for the population mean satisfaction score.

# %% [markdown]
# 14  Scenario: A company wants to analyze the effect of temperature on product performance. The data collected is as follows:
#     Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
#     Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#     Perform a simple linear regression to predict performance based on temperature.

# %% [markdown]
# To perform a simple linear regression to predict performance based on temperature, you can use the following steps:
#
# Step 1: Prepare the data.
# The data collected for temperature and performance is as follows:
#
# Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
# Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
# Make sure that the data is properly aligned, meaning that the performance ratings correspond to the correct temperature values.
#
# Step 2: Plot the data.
# Create a scatter plot with temperature on the x-axis and performance on the y-axis. Each data point represents a temperature-performance pair.
#
# Step 3: Calculate the correlation coefficient.
# Calculate the correlation coefficient (r) to determine the strength and direction of the linear relationship between temperature and performance. You can use a statistical software or a programming language with appropriate libraries to calculate the correlation coefficient. The correlation coefficient ranges between -1 and 1, where -1 indicates a strong negative correlation, 1 indicates a strong positive correlation, and 0 indicates no correlation.
#
# Step 4: Perform linear regression analysis.
# Perform a linear regression analysis to determine the equation of the regression line that best fits the data. The equation is typically in the form of y = mx + b, where y represents the predicted performance, x represents the temperature, m represents the slope of the line, and b represents the y-intercept.
#
# You can use statistical software or programming languages with appropriate libraries to perform linear regression analysis.
#
# Step 5: Interpret the results.
# Interpret the results of the linear regression analysis, including the slope, intercept, and the coefficient of determination (R-squared). The slope indicates how much the performance is expected to change for each unit change in temperature. The intercept represents the predicted performance when the temperature is zero. The R-squared value indicates the proportion of the variance in performance that can be explained by temperature.
#
# Performing these steps with the given data will provide you with the simple linear regression analysis results and allow you to predict performance based on temperature.

# %% [markdown]
# 15  Scenario: A study is conducted to compare the preferences of two groups of participants. The preferences are measured on a Likert scale from 1 to 5. The data collected is as follows:
#     Group A: [4, 3, 5, 2, 4]
#     Group B: [3, 2, 4, 3, 3]
# Perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between the two groups.

# %% [markdown]
# To perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between Group A and Group B, you can use the following steps:
#
# Step 1: State the null and alternative hypotheses.
# Null hypothesis (H0): There is no significant difference in the median preferences between Group A and Group B.
# Alternative hypothesis (Ha): There is a significant difference in the median preferences between Group A and Group B.
#
# Step 2: Rank the data.
# Rank the data from both groups combined, assigning a rank based on the order of the values, ignoring the group membership. If there are ties, assign the average rank to those tied values.
#
# Group A: [4, 3, 5, 2, 4]
# Group B: [3, 2, 4, 3, 3]
#
# Combined and ranked data: [4, 3, 5, 2, 4, 3, 2, 4, 3, 3]
# Ranked data: [6, 3.5, 10, 1, 6, 3.5, 1, 6, 3.5, 3.5]
#
# Step 3: Calculate the U statistic.
# Calculate the U statistic for each group, which is the sum of the ranks for the smaller group.
#
# Group A: U_A = Sum of ranks for Group A
# U_A = 6 + 3.5 + 6 + 1 + 6
# U_A = 22.5
#
# Group B: U_B = Sum of ranks for Group B
# U_B = 3.5 + 1 + 6 + 3.5 + 3.5
# U_B = 17
#
# Step 4: Calculate the minimum expected U value.
# Calculate the minimum expected U value for each group using the formula:
# Minimum expected U = (n1 * n2) / 2
#
# Where n1 is the sample size of Group A and n2 is the sample size of Group B.
#
# n1 = 5 (sample size of Group A)
# n2 = 5 (sample size of Group B)
#
# Minimum expected U = (5 * 5) / 2
# Minimum expected U = 12.5
#
# Step 5: Determine the critical value.
# Based on the chosen significance level (e.g., α = 0.05) and the sample sizes of both groups, you can use a Mann-Whitney U critical values table or statistical software to determine the critical value.
#
# Step 6: Compare the calculated U statistic with the critical value.
# If the calculated U statistic is less than or equal to the critical value, you fail to reject the null hypothesis. Otherwise, you reject the null hypothesis in favor of the alternative hypothesis.
#
# Step 7: Interpret the results.
# If the calculated U statistic is less than or equal to the critical value, you cannot conclude that there is a significant difference in the median preferences between Group A and Group B. On the other hand, if the calculated U statistic is greater than the critical value, you can conclude that there is a significant difference.
#
# Performing these steps with the given data and chosen significance level will allow you to perform the Mann-Whitney U test and determine if there is a significant difference in the median preferences between the two groups.

# %% [markdown]
# 16  Scenario: A company wants to analyze the distribution of customer ages. The data collected is as follows:
#     [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#     Calculate the interquartile range (IQR) of the ages.

# %% [markdown]
# To calculate the interquartile range (IQR) of the customer ages, you can use the provided data. The IQR represents the range between the first quartile (Q1) and the third quartile (Q3) and provides a measure of the spread or dispersion of the data. Here's how you can calculate the IQR:
#
# Organize the Data:
#
# Customer ages: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
# Sort the Data:
#
# Arrange the ages in ascending order: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
# Calculate Quartiles:
#
# Determine the first quartile (Q1) and the third quartile (Q3) using the formula:
# Q1 = (n + 1) / 4
# Q3 = 3 * (n + 1) / 4
# where n is the total number of data points.
# Identify the Quartiles:
#
# Using the above formulas, calculate Q1 and Q3:
# Q1 = (10 + 1) / 4 = 2.75 (rounded to the nearest whole number) = 3rd data point = 35
# Q3 = 3 * (10 + 1) / 4 = 8.25 (rounded to the nearest whole number) = 9th data point = 65
# Calculate the Interquartile Range (IQR):
#
# IQR = Q3 - Q1 = 65 - 35 = 30
# The interquartile range (IQR) of the customer ages is 30. This means that the middle 50% of the ages falls within the range of 35 to 65. The IQR is a useful measure of spread as it captures the range of values in which the majority of the data points lie.

# %% [markdown]
# 17  Scenario: A study is conducted to compare the performance of three different machine learning algorithms. The accuracy scores for each algorithm are as follows:
#     Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
#     Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
#     Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#     Perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the algorithms.

# %% [markdown]
# To calculate the interquartile range (IQR) of the ages, you can follow these steps:
#
# Step 1: Sort the data in ascending order.
# The data collected for customer ages is as follows:
# [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Sorting the data in ascending order gives:
# [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 2: Determine the lower quartile (Q1) and the upper quartile (Q3).
# To calculate the quartiles, you need to determine the values that divide the data into four equal parts.
#
# Q1: The lower quartile is the median of the lower half of the data.
# Q3: The upper quartile is the median of the upper half of the data.
#
# Since we have 10 data points, Q1 will be the median of the first 5 data points, and Q3 will be the median of the last 5 data points.
#
# Q1 = Median of [25, 30, 35, 40, 45]
# = 35
#
# Q3 = Median of [50, 55, 60, 65, 70]
# = 60
#
# Step 3: Calculate the interquartile range (IQR).
# The interquartile range (IQR) is the difference between the upper quartile (Q3) and the lower quartile (Q1).
#
# IQR = Q3 - Q1
# = 60 - 35
# = 25
#
# Therefore, the interquartile range (IQR) of the ages is 25.

# %% [markdown]
# 18  Scenario: A company wants to analyze the effect of price on sales. The data collected is as follows:
#     Price (in dollars): [10, 15, 12, 8, 14]
#     Sales: [100, 80, 90, 110, 95]
#     Perform a simple linear regression to predict
#
#  sales based on price.

# %% [markdown]
# To perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the algorithms, you can use the following steps:
#
# Step 1: State the null and alternative hypotheses.
# Null hypothesis (H0): There is no significant difference in the median accuracy scores between the algorithms.
# Alternative hypothesis (Ha): There is a significant difference in the median accuracy scores between the algorithms.
#
# Step 2: Rank the data.
# Combine the accuracy scores from all three algorithms and rank them in ascending order. Assign ranks to the values, with the lowest value receiving a rank of 1, the next lowest receiving a rank of 2, and so on. For ties, assign each tied value the average of the ranks they would have received.
#
# Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
# Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
# Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#
# Combined and ranked data: [0.78, 0.79, 0.80, 0.80, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.87, 0.88, 0.89, 0.90]
#
# Ranked data: [1, 2, 3.5, 3.5, 5, 6, 7, 8, 9, 10.5, 10.5, 12, 13, 14]
#
# Step 3: Calculate the sum of ranks for each group.
# Calculate the sum of ranks for each group (Algorithm A, Algorithm B, Algorithm C).
#
# Algorithm A: Sum of ranks = 1 + 2 + 3.5 + 5 + 6 = 17.5
# Algorithm B: Sum of ranks = 3.5 + 7 + 8 + 10.5 + 12 = 41
# Algorithm C: Sum of ranks = 9 + 10.5 + 13 + 14 = 46.5
#
# Step 4: Calculate the test statistic.
# Calculate the Kruskal-Wallis test statistic using the formula:
# H = (12 * (sum of ranks^2 / N)) - 3 * (N + 1)
#
# Where N is the total number of observations.
#
# N = 14 (total number of observations)
#
# H = (12 * ((17.5^2 / 14) + (41^2 / 14) + (46.5^2 / 14))) - 3 * (14 + 1)
# H = (12 * (306.25 / 14 + 1681 / 14 + 2162.25 / 14)) - 3 * 15
# H = (12 * (21.875 + 120.0714 + 154.4464)) - 45
# H = (12 * 296.3928) - 45
# H = 3556.714 - 45
# H = 3511.714
#
# Step 5: Determine the critical value.
# Based on the chosen significance level (e.g., α = 0.05) and the degrees of freedom (df = k - 1, where k is the number of groups), you can use a Kruskal-Wallis critical values table or statistical software to determine the critical value.
#
# df = 3 - 1 = 2
#
# Step 6: Compare the calculated test statistic with the critical value.
# If the calculated test statistic is greater than the critical value, you reject the null hypothesis. Otherwise, you fail to reject the null hypothesis.
#
# Step 7: Interpret the results.
# If the calculated test statistic is greater than the critical value, you can conclude that there is a significant difference in the median accuracy scores between the algorithms. On the other hand, if the calculated test statistic is not greater than the critical value, you cannot conclude that there is a significant difference.
#
# Performing these steps with the given data and chosen significance level will allow you to perform the Kruskal-Wallis test and determine if there is a significant difference in the median accuracy scores between the algorithms.

# %% [markdown]
# 19  Scenario: A survey is conducted to measure the satisfaction levels of customers with a new product. The data collected is as follows:
#     [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#     Calculate the standard error of the mean satisfaction score.

# %% [markdown]
# To calculate the standard error of the mean satisfaction score, you can follow these steps:
#
# Step 1: Prepare the data.
# The data collected for customer satisfaction levels is as follows:
#
# Satisfaction levels: [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#
# Step 2: Calculate the sample mean.
# Calculate the mean satisfaction score of the sample using the given data.
#
# Mean = (7 + 8 + 9 + 6 + 8 + 7 + 9 + 7 + 8 + 7) / 10
# Mean = 76 / 10
# Mean = 7.6
#
# Step 3: Calculate the sample standard deviation.
# Calculate the standard deviation of the sample to estimate the variability of the satisfaction scores.
#
# Standard Deviation = sqrt([(7 - 7.6)^2 + (8 - 7.6)^2 + (9 - 7.6)^2 + (6 - 7.6)^2 + (8 - 7.6)^2 + (7 - 7.6)^2 + (9 - 7.6)^2 + (7 - 7.6)^2 + (8 - 7.6)^2 + (7 - 7.6)^2] / 9)
# Standard Deviation = sqrt([(-0.6)^2 + (0.4)^2 + (1.4)^2 + (-1.6)^2 + (0.4)^2 + (-0.6)^2 + (1.4)^2 + (-0.6)^2 + (0.4)^2 + (-0.6)^2] / 9)
# Standard Deviation = sqrt([0.36 + 0.16 + 1.96 + 2.56 + 0.16 + 0.36 + 1.96 + 0.36 + 0.16 + 0.36] / 9)
# Standard Deviation = sqrt(9.32 / 9)
# Standard Deviation ≈ sqrt(1.0356)
# Standard Deviation ≈ 1.017
#
# Step 4: Calculate the standard error of the mean.
# The standard error of the mean is calculated by dividing the sample standard deviation by the square root of the sample size.
#
# Standard Error = Standard Deviation / sqrt(sample size)
# Standard Error = 1.017 / sqrt(10)
# Standard Error ≈ 0.322
#
# Therefore, the standard error of the mean satisfaction score is approximately 0.322.

# %% [markdown]
# 20  Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
#     Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#     Sales (in thousands): [25, 30, 28, 20, 26]
#     Perform a multiple regression analysis to predict sales based on advertising expenditure.

# %% [markdown]
# To perform a multiple regression analysis to predict sales based on advertising expenditure, you can use the following steps:
#
# Step 1: Prepare the data.
# The data collected for advertising expenditure and sales is as follows:
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Make sure that the data is properly aligned, meaning that the sales correspond to the correct advertising expenditure values.
#
# Step 2: Check the assumptions.
# Before performing a multiple regression analysis, it is important to check the assumptions of linearity, independence, homoscedasticity, and normality. These assumptions should be met for the results of the analysis to be valid.
#
# Step 3: Perform the multiple regression analysis.
# Perform the multiple regression analysis using statistical software or programming languages with appropriate libraries. The analysis will provide you with the regression equation that best fits the data.
#
# The regression equation is typically in the form of:
#
# Sales = b0 + b1 * Advertising Expenditure
#
# where b0 is the intercept, b1 is the coefficient for advertising expenditure, and Sales is the predicted sales based on the advertising expenditure.
#
# Step 4: Interpret the results.
# Interpret the results of the multiple regression analysis, including the coefficients, intercept, and measures of model fit such as R-squared. The coefficients represent the effect of advertising expenditure on sales. The intercept represents the predicted sales when the advertising expenditure is zero. The R-squared value indicates the proportion of the variance in sales that can be explained by the advertising expenditure.
#
# Performing these steps with the given data will provide you with the results of the multiple regression analysis and allow you to predict sales based on advertising expenditure.
